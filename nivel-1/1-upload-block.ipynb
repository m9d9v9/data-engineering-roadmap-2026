# %% [markdown]
# ## Using read_csv

# %%
import pandas as pd
from sqlalchemy import create_engine

# --------------------------------
# CONFIG
# --------------------------------
CSV_FILE = "../yellow_tripdata_2024-01.csv"
TABLE_NAME = "yellow_taxi_data"

# --------------------------------
# 1) Lectura completa del CSV
# --------------------------------
df = pd.read_csv(CSV_FILE)

# --------------------------------
# 2) Conexión a Postgres
# --------------------------------
engine = create_engine(
    "postgresql://root:root@localhost:5432/ny_taxi"
)

# --------------------------------
# 3) Creación de tabla (solo esquema)
# --------------------------------
df.head(n=0).to_sql(name=TABLE_NAME, con=engine, if_exists="replace")

# --------------------------------
# 4) Carga completa de datos
# --------------------------------
# %time df.to_sql(name=TABLE_NAME, con=engine, if_exists="append")
# Out:
# /tmp/ipykernel_3570/1002605402.py:13: DtypeWarning: Columns (0: store_and_fwd_flag) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(CSV_FILE)
# CPU times: user 1min 44s, sys: 33.4 s, total: 2min 17s
# Wall time: 3min 28s
# 624
